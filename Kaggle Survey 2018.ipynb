# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib_venn import venn2, venn3
from matplotlib import gridspec
import seaborn as sns
import plotly.graph_objs as go
import plotly.offline as py
from plotly import tools
py.init_notebook_mode(connected=True)
from wordcloud import WordCloud, STOPWORDS

import warnings
warnings.filterwarnings('ignore')
plt.rcParams.update({'font.size':12,
                    'xtick.labelsize':14,
                    'ytick.labelsize':14})
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df2018 = pd.read_csv('../input/kaggle-survey-2018/multipleChoiceResponses.csv',)
response = pd.read_csv('../input/kaggle-survey-2018/freeFormResponses.csv',)
schema = pd.read_csv('../input/kaggle-survey-2018/SurveySchema.csv')
print(df2018.shape)
print(response.shape)
print(schema.shape)
df = df2018[1:]
df.head()
# Out:
# (23860, 395)
# (23860, 35)
# (12, 52)
#   Time from Start to Finish (seconds)      Q1 Q1_OTHER_TEXT     Q2  \
# 1                                 710  Female            -1  45-49
# 2                                 434    Male            -1  30-34
# 3                                 718  Female            -1  30-34
# 4                                 621    Male            -1  35-39
# 5                                 731    Male            -1  22-24
#
#                          Q3                 Q4  \
# 1  United States of America    Doctoral degree
# 2                 Indonesia  Bachelor’s degree
# 3  United States of America    Master’s degree
# 4  United States of America    Master’s degree
# 5                     India    Master’s degree
#
#                                                   Q5              Q6  \
# 1                                              Other      Consultant
# 2                 Engineering (non-computer focused)           Other
# 3      Computer science (software engineering, etc.)  Data Scientist
# 4  Social sciences (anthropology, psychology, soc...    Not employed
# 5                          Mathematics or statistics    Data Analyst
#
#   Q6_OTHER_TEXT                         Q7  ... Q49_OTHER_TEXT Q50_Part_1  \
# 1            -1                      Other  ...             -1        NaN
# 2             0  Manufacturing/Fabrication  ...             -1        NaN
# 3            -1             I am a student  ...             -1        NaN
# 4            -1                        NaN  ...             -1        NaN
# 5            -1             I am a student  ...             -1        NaN
#
#            Q50_Part_2                             Q50_Part_3 Q50_Part_4  \
# 1                 NaN                                    NaN        NaN
# 2                 NaN                                    NaN        NaN
# 3  Too time-consuming                                    NaN        NaN
# 4                 NaN  Requires too much technical knowledge        NaN
# 5  Too time-consuming                                    NaN        NaN
#
#                                Q50_Part_5 Q50_Part_6 Q50_Part_7 Q50_Part_8  \
# 1                                     NaN        NaN        NaN        NaN
# 2                                     NaN        NaN        NaN        NaN
# 3                                     NaN        NaN        NaN        NaN
# 4  Not enough incentives to share my work        NaN        NaN        NaN
# 5  Not enough incentives to share my work        NaN        NaN        NaN
#
#   Q50_OTHER_TEXT
# 1             -1
# 2             -1
# 3             -1
# 4             -1
# 5             -1
#
# [5 rows x 395 columns]

# %%
def Horizontal_bar_plot(df, column, name='',title='',limit=None,colorscale = 'Picnic',width = 900, height = 500):
    tmp = df[column].value_counts()[:limit]
    tmp_per = round(tmp*100/tmp.sum(),2)
    tmp_per = [str(v)+' %' for v in tmp_per]
    trace1 = go.Bar(y = tmp.values, x = tmp.index, name=name, orientation='v',
                   marker=dict(color=tmp.values, colorscale = colorscale, line=dict(color='rgb(127,140,141)',width=2),),
                   text = tmp_per, textposition = 'outside',
                   )
    layout = dict(title = title,
                 width = width, height = height,
                 yaxis = dict(automargin = True,),
                 paper_bgcolor = 'rgb(251, 252, 252)',
                 plot_bgcolor = 'rgb(251, 252, 252)'
                 )
    fig = {'data':[trace1],'layout':layout}
    py.iplot(fig)

# %%
def Horizontal_Multi_Barplot(df, column, column_filter,title ='', height = 600, width = 850,
                             name = ['Student','Data Scientist','Data Analyst'],limit = None,):
    """ Bar plot"""
    colors = ['rgb (240,128,128)','rgb(0,255,255)','rgb(186,85,211)','rgb(210,105,30)','rgb(0,0,205)',
              'rgb(124,252,0)','rgb(255,99,71)',]
    # Layout
    fig = tools.make_subplots(rows= len(name), cols=1, #subplot_titles= tuple(name),
                              vertical_spacing = 0.05, horizontal_spacing = 0.05,
                              print_grid= False,shared_xaxes = True)
    
    fig['layout'].update(dict( 
        showlegend =False,
        height = height,
        width = width,
        title = title,
        paper_bgcolor='rgb(251, 252, 252)',
        plot_bgcolor='rgb(250, 250, 255)'))

    # Multi Plot
    for i, c in enumerate(name):
        #tmp = df[column].value_counts()[:limit]
        tmp = df[df[column_filter] == c][column].value_counts()[:limit]
        tmp_per = round(tmp * 100/ tmp.sum() , 2)
        tmp_per = [str(v)+' %' for v in tmp_per]
        
        # Plot
        trace1 = go.Bar(y = tmp.values, x = tmp.index, name= c,orientation='v',
            marker=dict(color = colors[i],line=dict(color='rgb( 127, 140, 141)',width=2),),
            text = tmp_per, textposition='auto', textfont = dict(size =13,family = 'Droid')
        )
        
        fig.append_trace(trace1, i+1,1)
        fig.layout[f'yaxis{i+1}'].update(title = c)

    # Final plot
    py.iplot(fig)

# %%
# 4 Pie plot
def Pie_plot_agg(filter_column = '',column = '',name = [], title = '', width = 1000, height= 600):
    
    """Draw four pie plot of
    filter_column is to filter out the perticual category mentioned in name variable
    column: This target column upon which pie plot is drwan
    name: Four different category of filter_column
    """
    # trace1
    tmp = (df[df[filter_column] == name[0]][column])
    tmp = tmp.value_counts(ascending = True)
    trace1 = go.Pie(labels= tmp.index, values= tmp.values, hoverinfo='label+percent+name', 
                    name = name[0],hole= .5, domain= dict(x = [0, 0.46], y = [0.54, 1]))
    
    # trace2
    tmp = (df[df[filter_column] == name[1]][column])
    tmp = tmp.value_counts(ascending = True)
    trace2= go.Pie(labels= tmp.index, values= tmp.values, hoverinfo='label+percent+name', 
                    name = name[1],hole= .5, domain= dict(x = [0.54,1],y = [0.54, 1]))
    #trace3
    tmp = (df[df[filter_column] == name[2]][column])
    tmp = tmp.value_counts(ascending = True)
    trace3 = go.Pie(labels= tmp.index, values= tmp.values, hoverinfo='label+percent+name', 
                    name = name[2],hole= .5, domain= dict(x = [0, 0.46],y = [0, 0.46]))
    #trace4
    tmp = (df[df[filter_column] == name[3]][column])
    tmp = tmp.value_counts(ascending = True)
    trace4 = go.Pie(labels= tmp.index, values= tmp.values, hoverinfo='label+percent+name', 
                    name = name[3],hole= .5, domain= dict(x = [0.54, 1],y = [0, 0.46]))

    # Layout
    layout = go.Layout(title = title, width = width, height = height,
                       annotations = [dict(font = dict(size=20)),
                                      dict(showarrow =False, text=name[0],x = 0.18, y=0.78),
                                      dict(font = dict(size=20)),
                                      dict(showarrow= False, text=name[1],x = 0.82, y=0.78),
                                      dict(font = dict(size=20)),
                                      dict(showarrow= False, text=name[2],x = 0.17, y=0.2),
                                      dict(font = dict(size=20)),
                                      dict(showarrow= False, text=name[3],x = 0.82, y=0.2),
                                ])
    fig = go.Figure(data = [trace1, trace2, trace3, trace4], layout= layout)
    py.iplot(fig)

# %%
def Venn2_diagram(df,columns):
    """ Venn diagram of 2 sets"""
    # Subset count
    label = df[columns].mode().values[0]
    subsets = (
        len(df[(df[columns[0]] == label[0]) & (df[columns[1]] != label[1])]), #A
        len(df[(df[columns[0]] != label[0]) & (df[columns[1]] == label[1])]), #B
        len(df[(df[columns[0]] == label[0]) & (df[columns[1]] == label[1])]), #A.B
             )
    return venn2(subsets = subsets, set_labels= label)

def Venn3_diagram(df,columns):
    """ Venn diagram of 3 sets"""
    # Subset count
    label = df[columns].mode().values[0]
    subsets = (
        len(df[(df[columns[0]] == label[0]) & (df[columns[1]] != label[1]) & (df[columns[2]] != label[2])]), #A
        len(df[(df[columns[0]] != label[0]) & (df[columns[1]] == label[1]) & (df[columns[2]] != label[2])]), #B
        len(df[(df[columns[0]] == label[0]) & (df[columns[1]] == label[1]) & (df[columns[2]] != label[2])]), #A.B
        len(df[(df[columns[0]] != label[0]) & (df[columns[1]] != label[1]) & (df[columns[2]] == label[2])]), #C
        len(df[(df[columns[0]] == label[0]) & (df[columns[1]] != label[1]) & (df[columns[2]] == label[2])]), #A.C
        len(df[(df[columns[0]] != label[0]) & (df[columns[1]] == label[1]) & (df[columns[2]] == label[2])]), #B.C
        len(df[(df[columns[0]] == label[0]) & (df[columns[1]] == label[1]) & (df[columns[2]] == label[2])]), #A.B.C
             )
    return venn3(subsets = subsets, set_labels= label)

# %%
#
tmp = df['Time from Start to Finish (seconds)'].astype('int')/60
tmp = tmp[tmp<100]
print('Mean time to anwser the quetions is:',round(np.mean(tmp),2), 'minutes')

# Plot
trace1 = go.Histogram(x = tmp, #nbinsx= 30, 
                      marker= dict(color='rgb(255, 65, 54)', line=dict(color='rgb( 127, 140, 141)',width=0.5)))
layout = dict(
        title='Duration in minute',
        width = 800,
        height = 400,
        xaxis = dict(autorange=True),
        yaxis=dict(automargin=True),
        paper_bgcolor='rgb(251, 252, 252)',
        plot_bgcolor='rgb(251, 252, 252)'
        )
fig = {'data':[trace1], 'layout':layout}
py.iplot(fig)
# Out:
# Mean time to anwser the quetions is: 18.72 minutes
# <div>
#
#
#             <div id="388dfeb0-90ab-464c-b9e0-3be932847a34" class="plotly-graph-div" style="height:400px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("388dfeb0-90ab-464c-b9e0-3be932847a34")) {
#                     Plotly.newPlot(
#                         '388dfeb0-90ab-464c-b9e0-3be932847a34',
#                         [{"marker": {"color": "rgb(255, 65, 54)", "line": {"color": "rgb( 127, 140, 141)", "width": 0.5}}, "type": "histogram", "x": [11.833333333333334, 7.233333333333333, 11.966666666666667, 10.35, 12.183333333333334, 19.033333333333335, 15.983333333333333, 29.3, 10.683333333333334, 12.516666666666667, 33.8, 13.716666666666667, 18.183333333333334, 31.95, 14.1, 19.216666666666665, 43.766666666666666, 23.133333333333333, 35.833333333333336, 22.683333333333334, 34.2, 40.96666666666667, 22.116666666666667, 19.616666666666667, 21.633333333333333, 16.866666666666667, 34.38333333333333, 54.43333333333333, 17.05, 23.65, 17.216666666666665, 22.4, 28.733333333333334, 19.383333333333333, 33.266666666666666, 16.183333333333334, 17.716666666666665, 40.53333333333333, 19.75, 15.25, 15.316666666666666, 26.366666666666667, 15.016666666666667, 17.883333333333333, 37.75, 14.5, 29.433333333333334, 20.533333333333335, 58.53333333333333, 20.133333333333333, 33.85, 17.866666666666667, 11.766666666666667, 15.55, 12.55, 18.05, 10.783333333333333, 15.7, 11.366666666666667, 13.916666666666666, 17.2, 12.033333333333333, 18.05, 31.416666666666668, 12.283333333333333, 25.5, 27.216666666666665, 21.816666666666666, 38.35, 24.45, 18.583333333333332, 7.966666666666667, 15.333333333333334, 49.166666666666664, 38.666666666666664, 25.1, 25.2, 14.3, 16.6, 9.866666666666667, 54.45, 40.766666666666666, 9.483333333333333, 19.583333333333332, 32.233333333333334, 17.166666666666668, 18.066666666666666, 8.55, 24.133333333333333, 8.483333333333333, 23.766666666666666, 29.05, 39.2, 19.283333333333335, 11.3, 25.816666666666666, 18.866666666666667, 23.316666666666666, 11.533333333333333, 40.3, 17.5, 22.433333333333334, 22.183333333333334, 15.116666666666667, 12.516666666666667, 13.95, 20.216666666666665, 28.2, 31.033333333333335, 6.833333333333333, 68.71666666666667, 30.133333333333333, 60.05, 14.133333333333333, 14.083333333333334, 37.36666666666667, 12.483333333333333, 18.583333333333332, 9.266666666666667, 26.066666666666666, 64.35, 12.916666666666666, 52.983333333333334, 17.4, 9.216666666666667, 16.816666666666666, 10.1, 12.416666666666666, 10.983333333333333, 13.316666666666666, 26.333333333333332, 8.0, 21.033333333333335, 17.1, 15.35, 10.9, 13.016666666666667, 27.4, 10.033333333333333, 11.716666666666667, 35.56666666666667, 12.1, 11.583333333333334, 19.933333333333334, 14.55, 13.033333333333333, 10.45, 13.016666666666667, 8.866666666666667, 23.5, 21.25, 29.65, 14.333333333333334, 14.7, 26.683333333333334, 21.666666666666668, 22.116666666666667, 20.733333333333334, 8.016666666666667, 28.1, 35.8, 39.8, 24.05, 26.783333333333335, 12.966666666666667, 22.366666666666667, 20.366666666666667, 17.583333333333332, 16.55, 27.716666666666665, 10.05, 23.266666666666666, 19.6, 38.483333333333334, 12.766666666666667, 27.416666666666668, 12.883333333333333, 20.333333333333332, 6.766666666666667, 11.333333333333334, 25.616666666666667, 9.85, 31.016666666666666, 38.583333333333336, 15.133333333333333, 19.35, 23.266666666666666, 13.383333333333333, 24.783333333333335, 34.2, 66.01666666666667, 16.583333333333332, 17.316666666666666, 59.516666666666666, 9.383333333333333, 2.066666666666667, 11.733333333333333, 10.7, 12.716666666666667, 16.283333333333335, 49.516666666666666, 7.55, 18.116666666666667, 18.516666666666666, 16.6, 17.683333333333334, 23.766666666666666, 20.3, 24.466666666666665, 18.75, 14.433333333333334, 30.733333333333334, 14.533333333333333, 21.566666666666666, 26.55, 10.416666666666666, 17.416666666666668, 11.516666666666667, 38.53333333333333, 96.48333333333333, 62.45, 14.916666666666666, 88.28333333333333, 18.133333333333333, 28.466666666666665, 26.4, 10.8, 22.533333333333335, 18.733333333333334, 20.933333333333334, 9.85, 17.2, 13.316666666666666, 12.866666666666667, 26.833333333333332, 22.383333333333333, 8.566666666666666, 18.083333333333332, 15.916666666666666, 22.0, 18.716666666666665, 10.85, 12.583333333333334, 13.166666666666666, 19.666666666666 ...

# %%
def Map(tmp, title = '', colorscale = 'Viridis',):
    """Geo map:"""
    data = dict( type = 'choropleth',
               locations = tmp.index,
               z = tmp.values,
               text = tmp. index,
               locationmode = 'country names',
               colorscale = False,
               reversescale =True,
               marker = dict(line = dict(
                             color = 'rgb(100,180,100)',width = 0.3
               ) ),
               colorbar = dict(autotick = False,
                              title = 'Response'),
               )
    layout = dict(
        title = title,
    geo = dict(showland =True,
              landcolor = "rgb(250, 250, 250)",
          showframe = False,
          showcoastlines =True,
          projection = dict(type = 'Mercator')
    ))
    fig = dict( data = [data], layout = layout )
    py.iplot(fig,validate=False, filename='word-map')

# %%
print(df2018['Q3'][0])
tmp = df['Q3'].value_counts()
title = '2018 Kaggle Survey - Response'
Map(tmp, title = title, colorscale='Viridis')
# Out:
# In which country do you currently reside?
# <div>
#
#
#             <div id="b589a028-f22b-479b-a689-233521663b1e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b589a028-f22b-479b-a689-233521663b1e")) {
#                     Plotly.newPlot(
#                         'b589a028-f22b-479b-a689-233521663b1e',
#                         [{"colorbar": {"autotick": false, "title": "Response"}, "colorscale": false, "locationmode": "country names", "locations": ["United States of America", "India", "China", "Other", "Russia", "Brazil", "Germany", "United Kingdom of Great Britain and Northern Ireland", "Canada", "France", "Japan", "Spain", "I do not wish to disclose my location", "Italy", "Australia", "Turkey", "Poland", "Netherlands", "Ukraine", "Nigeria", "Mexico", "South Korea", "Singapore", "Israel", "Indonesia", "Switzerland", "Pakistan", "Portugal", "Sweden", "South Africa", "Viet Nam", "Colombia", "Greece", "Argentina", "Malaysia", "Iran, Islamic Republic of...", "Belgium", "Bangladesh", "Denmark", "Ireland", "Egypt", "Hungary", "Belarus", "Kenya", "Peru", "Romania", "Finland", "New Zealand", "Chile", "Hong Kong (S.A.R.)", "Norway", "Tunisia", "Thailand", "Philippines", "Czech Republic", "Republic of Korea", "Morocco", "Austria"], "marker": {"line": {"color": "rgb(100,180,100)", "width": 0.3}}, "reversescale": true, "text": ["United States of America", "India", "China", "Other", "Russia", "Brazil", "Germany", "United Kingdom of Great Britain and Northern Ireland", "Canada", "France", "Japan", "Spain", "I do not wish to disclose my location", "Italy", "Australia", "Turkey", "Poland", "Netherlands", "Ukraine", "Nigeria", "Mexico", "South Korea", "Singapore", "Israel", "Indonesia", "Switzerland", "Pakistan", "Portugal", "Sweden", "South Africa", "Viet Nam", "Colombia", "Greece", "Argentina", "Malaysia", "Iran, Islamic Republic of...", "Belgium", "Bangladesh", "Denmark", "Ireland", "Egypt", "Hungary", "Belarus", "Kenya", "Peru", "Romania", "Finland", "New Zealand", "Chile", "Hong Kong (S.A.R.)", "Norway", "Tunisia", "Thailand", "Philippines", "Czech Republic", "Republic of Korea", "Morocco", "Austria"], "type": "choropleth", "z": [4716, 4417, 1644, 1036, 879, 736, 734, 702, 604, 604, 597, 485, 394, 355, 330, 327, 301, 270, 252, 208, 202, 188, 186, 173, 171, 164, 161, 155, 155, 147, 144, 128, 121, 119, 113, 113, 111, 107, 106, 101, 96, 93, 91, 85, 81, 79, 79, 77, 76, 76, 74, 74, 73, 73, 72, 71, 71, 62]}],
#                         {"geo": {"landcolor": "rgb(250, 250, 250)", "projection": {"type": "Mercator"}, "showcoastlines": true, "showframe": false, "showland": true}, "title": "2018 Kaggle Survey - Response"},
#                         {"responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('b589a028-f22b-479b-a689-233521663b1e');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
print(df2018['Q3'][0])
Horizontal_bar_plot(df, column = 'Q3', title = 'Top 20 Countries Response', limit =20)
df['Q3'].nunique()
# Out:
# In which country do you currently reside?
# <div>
#
#
#             <div id="c64de556-ef2f-40bc-869a-4d1370388b49" class="plotly-graph-div" style="height:500px; width:900px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c64de556-ef2f-40bc-869a-4d1370388b49")) {
#                     Plotly.newPlot(
#                         'c64de556-ef2f-40bc-869a-4d1370388b49',
#                         [{"marker": {"color": [4716, 4417, 1644, 1036, 879, 736, 734, 702, 604, 604, 597, 485, 394, 355, 330, 327, 301, 270, 252, 208], "colorscale": [[0.0, "rgb(0,0,255)"], [0.1, "rgb(51,153,255)"], [0.2, "rgb(102,204,255)"], [0.3, "rgb(153,204,255)"], [0.4, "rgb(204,204,255)"], [0.5, "rgb(255,255,255)"], [0.6, "rgb(255,204,255)"], [0.7, "rgb(255,153,255)"], [0.8, "rgb(255,102,204)"], [0.9, "rgb(255,102,102)"], [1.0, "rgb(255,0,0)"]], "line": {"color": "rgb(127,140,141)", "width": 2}}, "name": "", "orientation": "v", "text": ["24.07 %", "22.55 %", "8.39 %", "5.29 %", "4.49 %", "3.76 %", "3.75 %", "3.58 %", "3.08 %", "3.08 %", "3.05 %", "2.48 %", "2.01 %", "1.81 %", "1.68 %", "1.67 %", "1.54 %", "1.38 %", "1.29 %", "1.06 %"], "textposition": "outside", "type": "bar", "x": ["United States of America", "India", "China", "Other", "Russia", "Brazil", "Germany", "United Kingdom of Great Britain and Northern Ireland", "Canada", "France", "Japan", "Spain", "I do not wish to disclose my location", "Italy", "Australia", "Turkey", "Poland", "Netherlands", "Ukraine", "Nigeria"], "y": [4716, 4417, 1644, 1036, 879, 736, 734, 702, 604, 604, 597, 485, 394, 355, 330, 327, 301, 270, 252, 208]}],
#                         {"height": 500, "paper_bgcolor": "rgb(251, 252, 252)", "plot_bgcolor": "rgb(251, 252, 252)", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": ...
# 58

# %%
print(df2018['Q6'][0])
title = 'Current Role'
Horizontal_bar_plot(df, column = 'Q6', title=title, colorscale = 'Rainbow')
# Out:
# Select the title most similar to your current role (or most recent title if retired): - Selected Choice
# <div>
#
#
#             <div id="433522b7-2126-4517-b9e1-b048d9cd0a60" class="plotly-graph-div" style="height:500px; width:900px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("433522b7-2126-4517-b9e1-b048d9cd0a60")) {
#                     Plotly.newPlot(
#                         '433522b7-2126-4517-b9e1-b048d9cd0a60',
#                         [{"marker": {"color": [5253, 4137, 3130, 1922, 1322, 1189, 842, 785, 772, 737, 600, 590, 428, 360, 237, 145, 117, 115, 102, 97, 20], "colorscale": [[0.0, "rgb(150,0,90)"], [0.125, "rgb(0,0,200)"], [0.25, "rgb(0,25,255)"], [0.375, "rgb(0,152,255)"], [0.5, "rgb(44,255,150)"], [0.625, "rgb(151,255,0)"], [0.75, "rgb(255,234,0)"], [0.875, "rgb(255,111,0)"], [1.0, "rgb(255,0,0)"]], "line": {"color": "rgb(127,140,141)", "width": 2}}, "name": "", "orientation": "v", "text": ["22.94 %", "18.07 %", "13.67 %", "8.39 %", "5.77 %", "5.19 %", "3.68 %", "3.43 %", "3.37 %", "3.22 %", "2.62 %", "2.58 %", "1.87 %", "1.57 %", "1.03 %", "0.63 %", "0.51 %", "0.5 %", "0.45 %", "0.42 %", "0.09 %"], "textposition": "outside", "type": "bar", "x": ["Student", "Data Scientist", "Software Engineer", "Data Analyst", "Other", "Research Scientist", "Not employed", "Consultant", "Business Analyst", "Data Engineer", "Research Assistant", "Manager", "Product/Project Manager", "Chief Officer", "Statistician", "DBA/Database Engineer", "Developer Advocate", "Marketing Analyst", "Salesperson", "Principal Investigator", "Data Journalist"], "y": [5253, 4137, 3130, 1922, 1322, 1189, 842, 785, 772, 737, 600, 590, 428, 360, 237, 145, 117, 115, 102, 97, 20]}],
#                         {"height": 500, "paper_bgcolor": "rgb(251, 252, 252)", "plot_bgcolor": "rgb(251, 252, 252)", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": ...

# %%
print(df2018['Q3'][0], '\n', df2018['Q6'][0],)
title = 'Country Vs Current Role'
Pie_plot_agg(filter_column='Q3',
            column = 'Q6',
            title = title,
            name = ['United States of America', 
                    'India', 'China', 'Russia'],
            width = 1000, height = 800)
# Out:
# In which country do you currently reside?
#  Select the title most similar to your current role (or most recent title if retired): - Selected Choice
# <div>
#
#
#             <div id="6138c58d-9b46-4b78-acba-35e7fc689a61" class="plotly-graph-div" style="height:800px; width:1000px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6138c58d-9b46-4b78-acba-35e7fc689a61")) {
#                     Plotly.newPlot(
#                         '6138c58d-9b46-4b78-acba-35e7fc689a61',
#                         [{"domain": {"x": [0, 0.46], "y": [0.54, 1]}, "hole": 0.5, "hoverinfo": "label+percent+name", "labels": ["Data Journalist", "Developer Advocate", "DBA/Database Engineer", "Salesperson", "Marketing Analyst", "Principal Investigator", "Statistician", "Chief Officer", "Product/Project Manager", "Research Assistant", "Data Engineer", "Manager", "Not employed", "Consultant", "Business Analyst", "Research Scientist", "Other", "Data Analyst", "Software Engineer", "Student", "Data Scientist"], "name": "United States of America", "type": "pie", "values": [3, 13, 26, 27, 31, 37, 54, 92, 94, 130, 139, 144, 155, 175, 179, 210, 341, 417, 515, 856, 946]}, {"domain": {"x": [0.54, 1], "y": [0.54, 1]}, "hole": 0.5, "hoverinfo": "label+percent+name", "labels": ["Data Journalist", "Principal Investigator", "Statistician", "Developer Advocate", "Salesperson", "Marketing Analyst", "Chief Officer", "DBA/Database Engineer", "Research Assistant", "Product/Project Manager", "Research Scientist", "Manager", "Data Engineer", "Consultant", "Business Analyst", "Other", "Not employed", "Data Analyst", "Data Scientist", "Software Engineer", "Student"], "name": "India", "type": "pie", "values": [3, 4, 16, 16, 17, 22, 32, 33, 64, 75, 85, 90, 111, 116, 145, 229, 231, 356, 595, 687, 1323]}, {"domain": {"x": [0, 0.46], "y": [0, 0.46]}, "hole": 0.5, "hoverinfo": "label+percent+name", "labels": ["Data Journalist", "Marketing Analyst", "Salesperson", "Consultant", "Statistician", "DBA/Database Engineer", "Chief Officer", "Developer Advocate", "Manager", "Other", "Product/Project Manager", "Not employed", "Business Analyst", "Research Assistant", "Research Scientist", "Data Engineer", "Data Scientist", "Software Engineer", "Data Analyst", "Student"], "name": "China", "type": "pie", "values": [1, 2, 2, 6, 8, 9, 11, 12, 17, 21, 22, 26, 26, 39, 41, 94, 106, 166, 179, 715]}, {"domain": {"x": [0.54, 1], "y": [0, 0.46]}, "hole": 0.5, "hoverinfo": "label+percent+name", "labels": ["Developer Advocate", "Data Journalist", "Principal Investigator", "Statistician", "Marketing Analyst", "DBA/Database Engineer", "Consultant", "Chief Officer", "Research Assistant", "Product/Project Manager", "Data Engineer", "Manager", "Business Analyst", "Other", "Not employed", "Research Scientist", "Data Analyst", "Student", "Software Engineer", "Data Scientist"], "name": "Russia", "type": "pie", "values": [1, 1, 2, 3, 6, 11, 12, 16, 18, 21, 23, 27, 30, 41, 50, 55, 76, 113, 151, 178]}],
#                         {"annotations": [{"font": {"size": 20}}, {"showarrow": false, "text": "United States of America", "x": 0.18, "y": 0.78}, {"font": {"size": 20}}, {"showarrow": false, "text": "India", "x": 0.82, "y": 0.78}, {"font": {"size": 20}}, {"showarrow": false, "text": "China", "x": 0.17, "y": 0.2}, {"font": {"size": 20}}, {"showarrow": false, "text": "Russia", "x": 0.82, "y": 0.2}], "height": 800, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "tick ...

# %%
print(df2018['Q7'][0])
title = 'Current Employer'
Horizontal_bar_plot(df, column = 'Q7', title = title)
# Out:
# In what industry is your current employer/contract (or your most recent employer if retired)? - Selected Choice
# <div>
#
#
#             <div id="125848b5-8696-4685-9ea7-431aacbd27af" class="plotly-graph-div" style="height:500px; width:900px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("125848b5-8696-4685-9ea7-431aacbd27af")) {
#                     Plotly.newPlot(
#                         '125848b5-8696-4685-9ea7-431aacbd27af',
#                         [{"marker": {"color": [5584, 4658, 2749, 1433, 940, 871, 751, 636, 564, 563, 483, 454, 447, 374, 357, 278, 189, 177, 177], "colorscale": [[0.0, "rgb(0,0,255)"], [0.1, "rgb(51,153,255)"], [0.2, "rgb(102,204,255)"], [0.3, "rgb(153,204,255)"], [0.4, "rgb(204,204,255)"], [0.5, "rgb(255,255,255)"], [0.6, "rgb(255,204,255)"], [0.7, "rgb(255,153,255)"], [0.8, "rgb(255,102,204)"], [0.9, "rgb(255,102,102)"], [1.0, "rgb(255,0,0)"]], "line": {"color": "rgb(127,140,141)", "width": 2}}, "name": "", "orientation": "v", "text": ["25.75 %", "21.48 %", "12.68 %", "6.61 %", "4.33 %", "4.02 %", "3.46 %", "2.93 %", "2.6 %", "2.6 %", "2.23 %", "2.09 %", "2.06 %", "1.72 %", "1.65 %", "1.28 %", "0.87 %", "0.82 %", "0.82 %"], "textposition": "outside", "type": "bar", "x": ["Computers/Technology", "I am a student", "Academics/Education", "Accounting/Finance", "Other", "Online Service/Internet-based Services", "Medical/Pharmaceutical", "Government/Public Service", "Insurance/Risk Assessment", "Manufacturing/Fabrication", "Marketing/CRM", "Retail/Sales", "Energy/Mining", "Broadcasting/Communications", "Online Business/Internet-based Sales", "Shipping/Transportation", "Non-profit/Service", "Hospitality/Entertainment/Sports", "Military/Security/Defense"], "y": [5584, 4658, 2749, 1433, 940, 871, 751, 636, 564, 563, 483, 454, 447, 374, 357, 278, 189, 177, 177]}],
#                         {"height": 500, "paper_bgcolor": "rgb(251, 252, 252)", "plot_bgcolor": "rgb(251, 252, 252)", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": ...

# %%
title = 'Current Industry'
Horizontal_Multi_Barplot(df, column = 'Q7', column_filter = 'Q6', title = title, limit = None, width =1000)
# Out:
# <div>
#
#
#             <div id="683a9c2f-973e-414e-b61c-5c4d8572e36d" class="plotly-graph-div" style="height:600px; width:1000px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("683a9c2f-973e-414e-b61c-5c4d8572e36d")) {
#                     Plotly.newPlot(
#                         '683a9c2f-973e-414e-b61c-5c4d8572e36d',
#                         [{"marker": {"color": "rgb (240,128,128)", "line": {"color": "rgb( 127, 140, 141)", "width": 2}}, "name": "Student", "orientation": "v", "text": ["72.89 %", "13.17 %", "7.99 %", "0.89 %", "0.68 %", "0.52 %", "0.52 %", "0.52 %", "0.46 %", "0.41 %", "0.39 %", "0.33 %", "0.29 %", "0.27 %", "0.21 %", "0.15 %", "0.14 %", "0.1 %", "0.08 %"], "textfont": {"family": "Droid", "size": 13}, "textposition": "auto", "type": "bar", "x": ["I am a student", "Academics/Education", "Computers/Technology", "Accounting/Finance", "Medical/Pharmaceutical", "Manufacturing/Fabrication", "Energy/Mining", "Online Service/Internet-based Services", "Other", "Government/Public Service", "Retail/Sales", "Military/Security/Defense", "Marketing/CRM", "Insurance/Risk Assessment", "Online Business/Internet-based Sales", "Non-profit/Service", "Broadcasting/Communications", "Hospitality/Entertainment/Sports", "Shipping/Transportation"], "xaxis": "x", "y": [3770, 681, 413, 46, 35, 27, 27, 27, 24, 21, 20, 17, 15, 14, 11, 8, 7, 5, 4], "yaxis": "y"}, {"marker": {"color": "rgb(0,255,255)", "line": {"color": "rgb( 127, 140, 141)", "width": 2}}, "name": "Data Scientist", "orientation": "v", "text": ["31.11 %", "9.17 %", "6.91 %", "6.64 %", "5.9 %", "5.8 %", "4.72 %", "4.6 %", "4.03 %", "3.27 %", "2.83 %", "2.73 %", "2.68 %", "2.56 %", "2.29 %", "1.99 %", "1.11 %", "0.91 %", "0.74 %"], "textfont": {"family": "Droid", "size": 13}, "textposition": "auto", "type": "bar", "x": ["Computers/Technology", "Accounting/Finance", "I am a student", "Online Service/Internet-based Services", "Academics/Education", "Other", "Medical/Pharmaceutical", "Insurance/Risk Assessment", "Marketing/CRM", "Retail/Sales", "Government/Public Service", "Energy/Mining", "Online Business/Internet-based Sales", "Broadcasting/Communications", "Manufacturing/Fabrication", "Shipping/Transportation", "Hospitality/Entertainment/Sports", "Military/Security/Defense", "Non-profit/Service"], "xaxis": "x2", "y": [1265, 373, 281, 270, 240, 236, 192, 187, 164, 133, 115, 111, 109, 104, 93, 81, 45, 37, 30], "yaxis": "y2"}, {"marker": {"color": "rgb(186,85,211)", "line": {"color": "rgb( 127, 140, 141)", "width": 2}}, "name": "Data Analyst", "orientation": "v", "text": ["21.99 %", "10.83 %", "9.87 %", "7.42 %", "5.92 %", "5.02 %", "4.64 %", "4.64 %", "4.59 %", "4.59 %", "3.9 %", "3.26 %", "2.83 %", "2.72 %", "2.45 %", "2.08 %", "1.44 %", "1.44 %", "0.37 %"], "textfont": {"family": "Droid", "size": 13}, "textposition": "auto", "type": "bar", "x": ["Computers/Technology", "Accounting/Finance", "I am a student", "Academics/Education", "Other", "Government/Public Service", "Online Service/Internet-based Services", "Marketing/CRM", "Insurance/Risk Assessment", "Medical/Pharmaceutical", "Retail/Sales", "Energy/Mining", "Online Business/Internet-based Sales", "Broadcasting/Communications", "Manufacturing/Fabrication", "Non-profit/Service", "Hospitality/Entertainment/Sports", "Shipping/Transportation", "Military/Security/Defense"], "xaxis": "x3", "y": [412, 203, 185, 139, 111, 94, 87, 87, 86, 86, 73, 61, 53, 51, 46, 39, 27, 27, 7], "yaxis": "y3"}],
#                         {"height": 600, "paper_bgcolor": "rgb(251, 252, 252)", "plot_bgcolor": "rgb(250, 250, 255)", "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorb ...

# %%
title = 'Work Experience'
Horizontal_bar_plot(df, column = 'Q8', name = 'Year', title = title, limit = None,)
# Out:
# <div>
#
#
#             <div id="8f6548a0-b7f1-4d04-9ea0-886e8e74658e" class="plotly-graph-div" style="height:500px; width:900px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8f6548a0-b7f1-4d04-9ea0-886e8e74658e")) {
#                     Plotly.newPlot(
#                         '8f6548a0-b7f1-4d04-9ea0-886e8e74658e',
#                         [{"marker": {"color": [5898, 3745, 2577, 2524, 1751, 1512, 1488, 854, 384, 197, 171], "colorscale": [[0.0, "rgb(0,0,255)"], [0.1, "rgb(51,153,255)"], [0.2, "rgb(102,204,255)"], [0.3, "rgb(153,204,255)"], [0.4, "rgb(204,204,255)"], [0.5, "rgb(255,255,255)"], [0.6, "rgb(255,204,255)"], [0.7, "rgb(255,153,255)"], [0.8, "rgb(255,102,204)"], [0.9, "rgb(255,102,102)"], [1.0, "rgb(255,0,0)"]], "line": {"color": "rgb(127,140,141)", "width": 2}}, "name": "Year", "orientation": "v", "text": ["27.95 %", "17.75 %", "12.21 %", "11.96 %", "8.3 %", "7.17 %", "7.05 %", "4.05 %", "1.82 %", "0.93 %", "0.81 %"], "textposition": "outside", "type": "bar", "x": ["0-1", "1-2", "2-3", "5-10", "3-4", "10-15", "4-5", "15-20", "20-25", "30 +", "25-30"], "y": [5898, 3745, 2577, 2524, 1751, 1512, 1488, 854, 384, 197, 171]}],
#                         {"height": 500, "paper_bgcolor": "rgb(251, 252, 252)", "plot_bgcolor": "rgb(251, 252, 252)", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": ...

# %%
title = 'Work Experience of Data Professionals'
Horizontal_Multi_Barplot(df, column = 'Q8', column_filter = 'Q6', title = title, limit = None, width = 1000)
# Out:
# <div>
#
#
#             <div id="0dd65384-40a1-4504-bb68-eec3eaee9d92" class="plotly-graph-div" style="height:600px; width:1000px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0dd65384-40a1-4504-bb68-eec3eaee9d92")) {
#                     Plotly.newPlot(
#                         '0dd65384-40a1-4504-bb68-eec3eaee9d92',
#                         [{"marker": {"color": "rgb (240,128,128)", "line": {"color": "rgb( 127, 140, 141)", "width": 2}}, "name": "Student", "orientation": "v", "text": ["42.47 %", "16.69 %", "11.21 %", "8.94 %", "6.23 %", "4.87 %", "4.38 %", "4.34 %", "0.66 %", "0.13 %", "0.08 %"], "textfont": {"family": "Droid", "size": 13}, "textposition": "auto", "type": "bar", "x": ["0-1", "1-2", "2-3", "3-4", "4-5", "15-20", "5-10", "10-15", "20-25", "25-30", "30 +"], "xaxis": "x", "y": [2005, 788, 529, 422, 294, 230, 207, 205, 31, 6, 4], "yaxis": "y"}, {"marker": {"color": "rgb(0,255,255)", "line": {"color": "rgb( 127, 140, 141)", "width": 2}}, "name": "Data Scientist", "orientation": "v", "text": ["32.08 %", "23.55 %", "14.49 %", "8.71 %", "8.04 %", "6.87 %", "3.25 %", "1.44 %", "0.82 %", "0.4 %", "0.35 %"], "textfont": {"family": "Droid", "size": 13}, "textposition": "auto", "type": "bar", "x": ["0-1", "1-2", "2-3", "5-10", "3-4", "4-5", "10-15", "15-20", "20-25", "30 +", "25-30"], "xaxis": "x2", "y": [1293, 949, 584, 351, 324, 277, 131, 58, 33, 16, 14], "yaxis": "y2"}, {"marker": {"color": "rgb(186,85,211)", "line": {"color": "rgb( 127, 140, 141)", "width": 2}}, "name": "Data Analyst", "orientation": "v", "text": ["34.29 %", "19.58 %", "14.98 %", "9.95 %", "7.63 %", "6.44 %", "3.89 %", "1.57 %", "0.92 %", "0.38 %", "0.38 %"], "textfont": {"family": "Droid", "size": 13}, "textposition": "auto", "type": "bar", "x": ["0-1", "1-2", "2-3", "5-10", "3-4", "4-5", "10-15", "15-20", "20-25", "30 +", "25-30"], "xaxis": "x3", "y": [634, 362, 277, 184, 141, 119, 72, 29, 17, 7, 7], "yaxis": "y3"}],
#                         {"height": 600, "paper_bgcolor": "rgb(251, 252, 252)", "plot_bgcolor": "rgb(250, 250, 255)", "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorb ...

# %%
title = 'Gender'
Horizontal_Multi_Barplot(df, column= 'Q1', column_filter= 'Q6',title = title,height=500)
# Out:
# <div>
#
#
#             <div id="15e97f3d-f699-471b-b7c5-7953c7bbd089" class="plotly-graph-div" style="height:500px; width:850px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("15e97f3d-f699-471b-b7c5-7953c7bbd089")) {
#                     Plotly.newPlot(
#                         '15e97f3d-f699-471b-b7c5-7953c7bbd089',
#                         [{"marker": {"color": "rgb (240,128,128)", "line": {"color": "rgb( 127, 140, 141)", "width": 2}}, "name": "Student", "orientation": "v", "text": ["79.4 %", "19.25 %", "1.01 %", "0.34 %"], "textfont": {"family": "Droid", "size": 13}, "textposition": "auto", "type": "bar", "x": ["Male", "Female", "Prefer not to say", "Prefer to self-describe"], "xaxis": "x", "y": [4171, 1011, 53, 18], "yaxis": "y"}, {"marker": {"color": "rgb(0,255,255)", "line": {"color": "rgb( 127, 140, 141)", "width": 2}}, "name": "Data Scientist", "orientation": "v", "text": ["81.92 %", "16.61 %", "1.21 %", "0.27 %"], "textfont": {"family": "Droid", "size": 13}, "textposition": "auto", "type": "bar", "x": ["Male", "Female", "Prefer not to say", "Prefer to self-describe"], "xaxis": "x2", "y": [3389, 687, 50, 11], "yaxis": "y2"}, {"marker": {"color": "rgb(186,85,211)", "line": {"color": "rgb( 127, 140, 141)", "width": 2}}, "name": "Data Analyst", "orientation": "v", "text": ["76.8 %", "21.75 %", "1.25 %", "0.21 %"], "textfont": {"family": "Droid", "size": 13}, "textposition": "auto", "type": "bar", "x": ["Male", "Female", "Prefer not to say", "Prefer to self-describe"], "xaxis": "x3", "y": [1476, 418, 24, 4], "yaxis": "y3"}],
#                         {"height": 500, "paper_bgcolor": "rgb(251, 252, 252)", "plot_bgcolor": "rgb(250, 250, 255)", "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorb ...

# %%
title = 'Age'
Horizontal_Multi_Barplot(df, column= 'Q2', column_filter= 'Q6',title = title)
# Out:
# <div>
#
#
#             <div id="c1dc0034-ceb6-4bc6-a424-25bfed150f77" class="plotly-graph-div" style="height:600px; width:850px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c1dc0034-ceb6-4bc6-a424-25bfed150f77")) {
#                     Plotly.newPlot(
#                         'c1dc0034-ceb6-4bc6-a424-25bfed150f77',
#                         [{"marker": {"color": "rgb (240,128,128)", "line": {"color": "rgb( 127, 140, 141)", "width": 2}}, "name": "Student", "orientation": "v", "text": ["38.99 %", "36.34 %", "17.7 %", "4.26 %", "1.62 %", "0.61 %", "0.17 %", "0.17 %", "0.1 %", "0.02 %", "0.02 %"], "textfont": {"family": "Droid", "size": 13}, "textposition": "auto", "type": "bar", "x": ["18-21", "22-24", "25-29", "30-34", "35-39", "40-44", "45-49", "50-54", "55-59", "60-69", "80+"], "xaxis": "x", "y": [2048, 1909, 930, 224, 85, 32, 9, 9, 5, 1, 1], "yaxis": "y"}, {"marker": {"color": "rgb(0,255,255)", "line": {"color": "rgb( 127, 140, 141)", "width": 2}}, "name": "Data Scientist", "orientation": "v", "text": ["33.09 %", "21.1 %", "17.26 %", "11.17 %", "5.39 %", "5.32 %", "2.71 %", "1.81 %", "1.31 %", "0.7 %", "0.07 %", "0.07 %"], "textfont": {"family": "Droid", "size": 13}, "textposition": "auto", "type": "bar", "x": ["25-29", "30-34", "22-24", "35-39", "18-21", "40-44", "45-49", "50-54", "55-59", "60-69", "80+", "70-79"], "xaxis": "x2", "y": [1369, 873, 714, 462, 223, 220, 112, 75, 54, 29, 3, 3], "yaxis": "y2"}, {"marker": {"color": "rgb(186,85,211)", "line": {"color": "rgb( 127, 140, 141)", "width": 2}}, "name": "Data Analyst", "orientation": "v", "text": ["32.88 %", "23.26 %", "18.31 %", "8.22 %", "7.02 %", "4.47 %", "2.55 %", "1.51 %", "0.94 %", "0.57 %", "0.16 %", "0.1 %"], "textfont": {"family": "Droid", "size": 13}, "textposition": "auto", "type": "bar", "x": ["25-29", "22-24", "30-34", "35-39", "18-21", "40-44", "45-49", "50-54", "55-59", "60-69", "70-79", "80+"], "xaxis": "x3", "y": [632, 447, 352, 158, 135, 86, 49, 29, 18, 11, 3, 2], "yaxis": "y3"}],
#                         {"height": 600, "paper_bgcolor": "rgb(251, 252, 252)", "plot_bgcolor": "rgb(250, 250, 255)", "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorb ...

# %%
print(df2018['Q5'][0])
title = 'Graduate Major'
Horizontal_bar_plot(df, column= 'Q5', name='Year',title= title, height= 500)
# Out:
# Which best describes your undergraduate major? - Selected Choice
# <div>
#
#
#             <div id="ee4f60c9-b693-4e8c-b697-9ebf76166661" class="plotly-graph-div" style="height:500px; width:900px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ee4f60c9-b693-4e8c-b697-9ebf76166661")) {
#                     Plotly.newPlot(
#                         'ee4f60c9-b693-4e8c-b697-9ebf76166661',
#                         [{"marker": {"color": [9430, 3705, 2950, 1791, 1110, 1029, 871, 770, 554, 269, 253, 128, 87], "colorscale": [[0.0, "rgb(0,0,255)"], [0.1, "rgb(51,153,255)"], [0.2, "rgb(102,204,255)"], [0.3, "rgb(153,204,255)"], [0.4, "rgb(204,204,255)"], [0.5, "rgb(255,255,255)"], [0.6, "rgb(255,204,255)"], [0.7, "rgb(255,153,255)"], [0.8, "rgb(255,102,204)"], [0.9, "rgb(255,102,102)"], [1.0, "rgb(255,0,0)"]], "line": {"color": "rgb(127,140,141)", "width": 2}}, "name": "Year", "orientation": "v", "text": ["41.09 %", "16.15 %", "12.86 %", "7.8 %", "4.84 %", "4.48 %", "3.8 %", "3.36 %", "2.41 %", "1.17 %", "1.1 %", "0.56 %", "0.38 %"], "textposition": "outside", "type": "bar", "x": ["Computer science (software engineering, etc.)", "Engineering (non-computer focused)", "Mathematics or statistics", "A business discipline (accounting, economics, finance, etc.)", "Physics or astronomy", "Information technology, networking, or system administration", "Medical or life sciences (biology, chemistry, medicine, etc.)", "Other", "Social sciences (anthropology, psychology, sociology, etc.)", "Humanities (history, literature, philosophy, etc.)", "Environmental science or geology", "I never declared a major", "Fine arts or performing arts"], "y": [9430, 3705, 2950, 1791, 1110, 1029, 871, 770, 554, 269, 253, 128, 87]}],
#                         {"height": 500, "paper_bgcolor": "rgb(251, 252, 252)", "plot_bgcolor": "rgb(251, 252, 252)", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": ...

# %%
title = 'Graduate Major'
Horizontal_Multi_Barplot(df, column= 'Q5', column_filter= 'Q6',title = title,)
# Out:
# <div>
#
#
#             <div id="bec298a8-227a-4930-8e16-bdefe0ca8d79" class="plotly-graph-div" style="height:600px; width:850px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("bec298a8-227a-4930-8e16-bdefe0ca8d79")) {
#                     Plotly.newPlot(
#                         'bec298a8-227a-4930-8e16-bdefe0ca8d79',
#                         [{"marker": {"color": "rgb (240,128,128)", "line": {"color": "rgb( 127, 140, 141)", "width": 2}}, "name": "Student", "orientation": "v", "text": ["50.15 %", "14.78 %", "10.54 %", "5.66 %", "4.61 %", "4.28 %", "3.4 %", "2.61 %", "1.52 %", "1.04 %", "0.63 %", "0.56 %", "0.23 %"], "textfont": {"family": "Droid", "size": 13}, "textposition": "auto", "type": "bar", "x": ["Computer science (software engineering, etc.)", "Engineering (non-computer focused)", "Mathematics or statistics", "Information technology, networking, or system administration", "A business discipline (accounting, economics, finance, etc.)", "Other", "Medical or life sciences (biology, chemistry, medicine, etc.)", "Physics or astronomy", "Social sciences (anthropology, psychology, sociology, etc.)", "Environmental science or geology", "I never declared a major", "Humanities (history, literature, philosophy, etc.)", "Fine arts or performing arts"], "xaxis": "x", "y": [2613, 770, 549, 295, 240, 223, 177, 136, 79, 54, 33, 29, 12], "yaxis": "y"}, {"marker": {"color": "rgb(0,255,255)", "line": {"color": "rgb( 127, 140, 141)", "width": 2}}, "name": "Data Scientist", "orientation": "v", "text": ["34.09 %", "20.29 %", "15.67 %", "8.24 %", "7.07 %", "3.55 %", "2.79 %", "2.6 %", "2.53 %", "1.29 %", "1.26 %", "0.36 %", "0.24 %"], "textfont": {"family": "Droid", "size": 13}, "textposition": "auto", "type": "bar", "x": ["Computer science (software engineering, etc.)", "Mathematics or statistics", "Engineering (non-computer focused)", "Physics or astronomy", "A business discipline (accounting, economics, finance, etc.)", "Medical or life sciences (biology, chemistry, medicine, etc.)", "Other", "Social sciences (anthropology, psychology, sociology, etc.)", "Information technology, networking, or system administration", "Environmental science or geology", "Humanities (history, literature, philosophy, etc.)", "I never declared a major", "Fine arts or performing arts"], "xaxis": "x2", "y": [1403, 835, 645, 339, 291, 146, 115, 107, 104, 53, 52, 15, 10], "yaxis": "y2"}, {"marker": {"color": "rgb(186,85,211)", "line": {"color": "rgb( 127, 140, 141)", "width": 2}}, "name": "Data Analyst", "orientation": "v", "text": ["28.24 %", "19.53 %", "14.02 %", "13.39 %", "5.62 %", "4.09 %", "3.99 %", "3.94 %", "3.25 %", "1.84 %", "1.31 %", "0.47 %", "0.31 %"], "textfont": {"family": "Droid", "size": 13}, "textposition": "auto", "type": "bar", "x": ["Computer science (software engineering, etc.)", "Mathematics or statistics", "A business discipline (accounting, economics, finance, etc.)", "Engineering (non-computer focused)", "Information technology, networking, or system administration", "Social sciences (anthropology, psychology, sociology, etc.)", "Physics or astronomy", "Medical or life sciences (biology, chemistry, medicine, etc.)", "Other", "Environmental science or geology", "Humanities (history, literature, philosophy, etc.)", "Fine arts or performing arts", "I never declared a major"], "xaxis": "x3", "y": [538, 372, 267, 255, 107, 78, 76, 75, 62, 35, 25, 9, 6], "yaxis": "y3"}],
#                         {"height": 600, "paper_bgcolor": "rgb(251, 252, 252)", "plot_bgcolor": "rgb(250, 250, 255)", "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorb ...

# %%
Pie_plot_agg(filter_column= 'Q3',
            column = 'Q5',
             title = 'Graduate major from top 4 countries',
            name = ['United States of America','India', 'China', 'Russia'],
            width = 1100, height =800)
# Out:
# <div>
#
#
#             <div id="bb19b23e-f6b0-4a73-9690-5a3212e33827" class="plotly-graph-div" style="height:800px; width:1100px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("bb19b23e-f6b0-4a73-9690-5a3212e33827")) {
#                     Plotly.newPlot(
#                         'bb19b23e-f6b0-4a73-9690-5a3212e33827',
#                         [{"domain": {"x": [0, 0.46], "y": [0.54, 1]}, "hole": 0.5, "hoverinfo": "label+percent+name", "labels": ["I never declared a major", "Fine arts or performing arts", "Environmental science or geology", "Humanities (history, literature, philosophy, etc.)", "Information technology, networking, or system administration", "Other", "Physics or astronomy", "Social sciences (anthropology, psychology, sociology, etc.)", "Medical or life sciences (biology, chemistry, medicine, etc.)", "A business discipline (accounting, economics, finance, etc.)", "Mathematics or statistics", "Engineering (non-computer focused)", "Computer science (software engineering, etc.)"], "name": "United States of America", "type": "pie", "values": [21, 42, 64, 124, 141, 209, 254, 270, 285, 540, 715, 748, 1201]}, {"domain": {"x": [0.54, 1], "y": [0.54, 1]}, "hole": 0.5, "hoverinfo": "label+percent+name", "labels": ["Fine arts or performing arts", "Social sciences (anthropology, psychology, sociology, etc.)", "Humanities (history, literature, philosophy, etc.)", "Environmental science or geology", "I never declared a major", "Physics or astronomy", "Medical or life sciences (biology, chemistry, medicine, etc.)", "A business discipline (accounting, economics, finance, etc.)", "Other", "Information technology, networking, or system administration", "Mathematics or statistics", "Engineering (non-computer focused)", "Computer science (software engineering, etc.)"], "name": "India", "type": "pie", "values": [2, 5, 8, 8, 20, 61, 69, 104, 155, 190, 268, 1038, 2361]}, {"domain": {"x": [0, 0.46], "y": [0, 0.46]}, "hole": 0.5, "hoverinfo": "label+percent+name", "labels": ["Humanities (history, literature, philosophy, etc.)", "Fine arts or performing arts", "I never declared a major", "Social sciences (anthropology, psychology, sociology, etc.)", "Other", "Environmental science or geology", "Physics or astronomy", "Medical or life sciences (biology, chemistry, medicine, etc.)", "A business discipline (accounting, economics, finance, etc.)", "Information technology, networking, or system administration", "Mathematics or statistics", "Engineering (non-computer focused)", "Computer science (software engineering, etc.)"], "name": "China", "type": "pie", "values": [5, 6, 10, 22, 31, 34, 40, 54, 70, 149, 169, 227, 715]}, {"domain": {"x": [0.54, 1], "y": [0, 0.46]}, "hole": 0.5, "hoverinfo": "label+percent+name", "labels": ["Fine arts or performing arts", "I never declared a major", "Environmental science or geology", "Humanities (history, literature, philosophy, etc.)", "Other", "Social sciences (anthropology, psychology, sociology, etc.)", "Medical or life sciences (biology, chemistry, medicine, etc.)", "Information technology, networking, or system administration", "Physics or astronomy", "Engineering (non-computer focused)", "A business discipline (accounting, economics, finance, etc.)", "Mathematics or statistics", "Computer science (software engineering, etc.)"], "name": "Russia", "type": "pie", "values": [1, 7, 8, 10, 11, 14, 18, 53, 67, 69, 70, 148, 333]}],
#                         {"annotations": [{"font": {"size": 20}}, {"showarrow": false, "text": "United States of America", "x": 0.18, "y": 0.78}, {"font": {"size": 20}}, {"showarrow": false, "text": "India", "x": 0.82, "y": 0.78}, {"font": {"size": 20}}, {"showarrow": false, "text": "China", "x": 0.17, "y": 0.2}, {"font": {"size": 20}}, {"showarrow": false, "text": "Russia", "x": 0.82, "y": 0.2}], "height": 800, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "tick ...

# %%
print(df2018['Q4'][0])
title = 'Highest Level of Education'
Horizontal_bar_plot(df, column = 'Q4', name = 'Year', title = title)
# Out:
# What is the highest level of formal education that you have attained or plan to attain within the next 2 years?
# <div>
#
#
#             <div id="f74ccb6a-c271-40e5-83ba-54d193fed481" class="plotly-graph-div" style="height:500px; width:900px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f74ccb6a-c271-40e5-83ba-54d193fed481")) {
#                     Plotly.newPlot(
#                         'f74ccb6a-c271-40e5-83ba-54d193fed481',
#                         [{"marker": {"color": [10855, 7083, 3357, 967, 599, 345, 232], "colorscale": [[0.0, "rgb(0,0,255)"], [0.1, "rgb(51,153,255)"], [0.2, "rgb(102,204,255)"], [0.3, "rgb(153,204,255)"], [0.4, "rgb(204,204,255)"], [0.5, "rgb(255,255,255)"], [0.6, "rgb(255,204,255)"], [0.7, "rgb(255,153,255)"], [0.8, "rgb(255,102,204)"], [0.9, "rgb(255,102,102)"], [1.0, "rgb(255,0,0)"]], "line": {"color": "rgb(127,140,141)", "width": 2}}, "name": "Year", "orientation": "v", "text": ["46.31 %", "30.22 %", "14.32 %", "4.13 %", "2.56 %", "1.47 %", "0.99 %"], "textposition": "outside", "type": "bar", "x": ["Master\u2019s degree", "Bachelor\u2019s degree", "Doctoral degree", "Some college/university study without earning a bachelor\u2019s degree", "Professional degree", "I prefer not to answer", "No formal education past high school"], "y": [10855, 7083, 3357, 967, 599, 345, 232]}],
#                         {"height": 500, "paper_bgcolor": "rgb(251, 252, 252)", "plot_bgcolor": "rgb(251, 252, 252)", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": ...

# %%
title = 'Highest level of Education'
Horizontal_Multi_Barplot(df, column = 'Q4', column_filter = 'Q6', title = title)
# Out:
# <div>
#
#
#             <div id="35c8a908-e851-4709-8377-4d6fa2503e86" class="plotly-graph-div" style="height:600px; width:850px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("35c8a908-e851-4709-8377-4d6fa2503e86")) {
#                     Plotly.newPlot(
#                         '35c8a908-e851-4709-8377-4d6fa2503e86',
#                         [{"marker": {"color": "rgb (240,128,128)", "line": {"color": "rgb( 127, 140, 141)", "width": 2}}, "name": "Student", "orientation": "v", "text": ["41.6 %", "40.49 %", "8.11 %", "7.18 %", "0.97 %", "0.84 %", "0.82 %"], "textfont": {"family": "Droid", "size": 13}, "textposition": "auto", "type": "bar", "x": ["Master\u2019s degree", "Bachelor\u2019s degree", "Doctoral degree", "Some college/university study without earning a bachelor\u2019s degree", "Professional degree", "I prefer not to answer", "No formal education past high school"], "xaxis": "x", "y": [2185, 2127, 426, 377, 51, 44, 43], "yaxis": "y"}, {"marker": {"color": "rgb(0,255,255)", "line": {"color": "rgb( 127, 140, 141)", "width": 2}}, "name": "Data Scientist", "orientation": "v", "text": ["55.5 %", "20.18 %", "18.81 %", "2.2 %", "1.93 %", "0.85 %", "0.53 %"], "textfont": {"family": "Droid", "size": 13}, "textposition": "auto", "type": "bar", "x": ["Master\u2019s degree", "Bachelor\u2019s degree", "Doctoral degree", "Some college/university study without earning a bachelor\u2019s degree", "Professional degree", "I prefer not to answer", "No formal education past high school"], "xaxis": "x2", "y": [2296, 835, 778, 91, 80, 35, 22], "yaxis": "y2"}, {"marker": {"color": "rgb(186,85,211)", "line": {"color": "rgb( 127, 140, 141)", "width": 2}}, "name": "Data Analyst", "orientation": "v", "text": ["51.56 %", "33.82 %", "6.5 %", "3.49 %", "2.45 %", "1.3 %", "0.88 %"], "textfont": {"family": "Droid", "size": 13}, "textposition": "auto", "type": "bar", "x": ["Master\u2019s degree", "Bachelor\u2019s degree", "Doctoral degree", "Some college/university study without earning a bachelor\u2019s degree", "Professional degree", "I prefer not to answer", "No formal education past high school"], "xaxis": "x3", "y": [991, 650, 125, 67, 47, 25, 17], "yaxis": "y3"}],
#                         {"height": 600, "paper_bgcolor": "rgb(251, 252, 252)", "plot_bgcolor": "rgb(250, 250, 255)", "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorb ...

# %%
print(df2018['Q9'][0])
title = 'Yearly Compensation'
Horizontal_bar_plot(df, column = 'Q9', title = title)
# Out:
# What is your current yearly compensation (approximate $USD)?
# <div>
#
#
#             <div id="ca3b9cb5-8c00-42f4-9c91-a49ea5026882" class="plotly-graph-div" style="height:500px; width:900px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ca3b9cb5-8c00-42f4-9c91-a49ea5026882")) {
#                     Plotly.newPlot(
#                         'ca3b9cb5-8c00-42f4-9c91-a49ea5026882',
#                         [{"marker": {"color": [4756, 4398, 1937, 1395, 1119, 965, 919, 843, 729, 677, 566, 533, 506, 457, 172, 75, 63, 52, 23], "colorscale": [[0.0, "rgb(0,0,255)"], [0.1, "rgb(51,153,255)"], [0.2, "rgb(102,204,255)"], [0.3, "rgb(153,204,255)"], [0.4, "rgb(204,204,255)"], [0.5, "rgb(255,255,255)"], [0.6, "rgb(255,204,255)"], [0.7, "rgb(255,153,255)"], [0.8, "rgb(255,102,204)"], [0.9, "rgb(255,102,102)"], [1.0, "rgb(255,0,0)"]], "line": {"color": "rgb(127,140,141)", "width": 2}}, "name": "", "orientation": "v", "text": ["23.56 %", "21.79 %", "9.6 %", "6.91 %", "5.54 %", "4.78 %", "4.55 %", "4.18 %", "3.61 %", "3.35 %", "2.8 %", "2.64 %", "2.51 %", "2.26 %", "0.85 %", "0.37 %", "0.31 %", "0.26 %", "0.11 %"], "textposition": "outside", "type": "bar", "x": ["I do not wish to disclose my approximate yearly compensation", "0-10,000", "10-20,000", "20-30,000", "30-40,000", "40-50,000", "50-60,000", "100-125,000", "60-70,000", "70-80,000", "90-100,000", "125-150,000", "80-90,000", "150-200,000", "200-250,000", "250-300,000", "500,000+", "300-400,000", "400-500,000"], "y": [4756, 4398, 1937, 1395, 1119, 965, 919, 843, 729, 677, 566, 533, 506, 457, 172, 75, 63, 52, 23]}],
#                         {"height": 500, "paper_bgcolor": "rgb(251, 252, 252)", "plot_bgcolor": "rgb(251, 252, 252)", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": ...

# %%
title = 'Current Yearly Compensation in Current Role'
Horizontal_Multi_Barplot(df, column= 'Q9', column_filter= 'Q6',title = title)
# Out:
# <div>
#
#
#             <div id="4fdc4436-2690-4f81-9ef2-79492da416f3" class="plotly-graph-div" style="height:600px; width:850px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4fdc4436-2690-4f81-9ef2-79492da416f3")) {
#                     Plotly.newPlot(
#                         '4fdc4436-2690-4f81-9ef2-79492da416f3',
#                         [{"marker": {"color": "rgb (240,128,128)", "line": {"color": "rgb( 127, 140, 141)", "width": 2}}, "name": "Student", "orientation": "v", "text": ["45.77 %", "39.77 %", "6.11 %", "3.47 %", "2.05 %", "0.9 %", "0.46 %", "0.25 %", "0.25 %", "0.25 %", "0.21 %", "0.14 %", "0.14 %", "0.09 %", "0.07 %", "0.05 %", "0.02 %"], "textfont": {"family": "Droid", "size": 13}, "textposition": "auto", "type": "bar", "x": ["0-10,000", "I do not wish to disclose my approximate yearly compensation", "10-20,000", "20-30,000", "30-40,000", "40-50,000", "50-60,000", "90-100,000", "70-80,000", "100-125,000", "60-70,000", "125-150,000", "80-90,000", "500,000+", "150-200,000", "200-250,000", "300-400,000"], "xaxis": "x", "y": [1991, 1730, 266, 151, 89, 39, 20, 11, 11, 11, 9, 6, 6, 4, 3, 2, 1], "yaxis": "y"}, {"marker": {"color": "rgb(0,255,255)", "line": {"color": "rgb( 127, 140, 141)", "width": 2}}, "name": "Data Scientist", "orientation": "v", "text": ["16.74 %", "11.81 %", "8.89 %", "6.92 %", "6.84 %", "6.71 %", "6.64 %", "5.87 %", "5.3 %", "4.92 %", "4.89 %", "4.61 %", "3.82 %", "3.72 %", "1.18 %", "0.41 %", "0.31 %", "0.26 %", "0.15 %"], "textfont": {"family": "Droid", "size": 13}, "textposition": "auto", "type": "bar", "x": ["I do not wish to disclose my approximate yearly compensation", "0-10,000", "10-20,000", "20-30,000", "100-125,000", "40-50,000", "30-40,000", "50-60,000", "70-80,000", "60-70,000", "125-150,000", "90-100,000", "80-90,000", "150-200,000", "200-250,000", "250-300,000", "300-400,000", "500,000+", "400-500,000"], "xaxis": "x2", "y": [653, 461, 347, 270, 267, 262, 259, 229, 207, 192, 191, 180, 149, 145, 46, 16, 12, 10, 6], "yaxis": "y2"}, {"marker": {"color": "rgb(186,85,211)", "line": {"color": "rgb( 127, 140, 141)", "width": 2}}, "name": "Data Analyst", "orientation": "v", "text": ["20.95 %", "19.59 %", "12.22 %", "7.6 %", "6.36 %", "5.63 %", "5.57 %", "5.41 %", "4.45 %", "3.77 %", "3.72 %", "2.59 %", "1.07 %", "0.45 %", "0.17 %", "0.17 %", "0.11 %", "0.11 %", "0.06 %"], "textfont": {"family": "Droid", "size": 13}, "textposition": "auto", "type": "bar", "x": ["0-10,000", "I do not wish to disclose my approximate yearly compensation", "10-20,000", "20-30,000", "30-40,000", "40-50,000", "50-60,000", "60-70,000", "70-80,000", "100-125,000", "80-90,000", "90-100,000", "125-150,000", "150-200,000", "500,000+", "400-500,000", "200-250,000", "300-400,000", "250-300,000"], "xaxis": "x3", "y": [372, 348, 217, 135, 113, 100, 99, 96, 79, 67, 66, 46, 19, 8, 3, 3, 2, 2, 1], "yaxis": "y3"}],
#                         {"height": 600, "paper_bgcolor": "rgb(251, 252, 252)", "plot_bgcolor": "rgb(250, 250, 255)", "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorb ...
